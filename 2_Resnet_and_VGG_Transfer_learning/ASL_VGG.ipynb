# %%
import numpy as np

df = np.load('/content/drive/MyDrive/alkfjdsl2.npy')
df
# Out:
# array([[[[-0.7411765 , -0.45882353, -0.4117647 ],
#          [-0.5921569 , -0.30980393, -0.2627451 ],
#          [-0.5372549 , -0.22352941, -0.2       ],
#          ...,
#          [ 0.6627451 ,  0.7019608 ,  0.7882353 ],
#          [ 0.6313726 ,  0.67058825,  0.77254903],
#          [ 0.6313726 ,  0.67058825,  0.77254903]],
#
#         [[-0.7254902 , -0.44313726, -0.39607844],
#          [-0.6156863 , -0.33333334, -0.28627452],
#          [-0.54509807, -0.23137255, -0.20784314],
#          ...,
#          [ 0.6313726 ,  0.67058825,  0.75686276],
#          [ 0.6313726 ,  0.67058825,  0.77254903],
#          [ 0.6392157 ,  0.6784314 ,  0.78039217]],
#
#         [[-0.7176471 , -0.43529412, -0.3882353 ],
#          [-0.5921569 , -0.30980393, -0.2627451 ],
#          [-0.5372549 , -0.22352941, -0.2       ],
#          ...,
#          [ 0.6392157 ,  0.6784314 ,  0.78039217],
#          [ 0.6392157 ,  0.6784314 ,  0.78039217],
#          [ 0.654902  ,  0.69411767,  0.79607844]],
#
#         ...,
#
#         [[-0.19215687, -0.12156863,  0.03529412],
#          [-0.19215687, -0.11372549,  0.01960784],
#          [-0.21568628, -0.11372549,  0.01176471],
#          ...,
#          [ 0.22352941,  0.31764707,  0.7882353 ],
#          [ 0.23137255,  0.2627451 ,  0.3882353 ],
#          [ 0.21568628,  0.2627451 ,  0.33333334]],
#
#         [[-0.2627451 , -0.13725491, -0.02745098],
#          [-0.29411766, -0.16862746, -0.05882353],
#          [-0.3019608 , -0.16862746, -0.05882353],
#          ...,
#          [ 0.23137255,  0.27058825,  0.40392157],
#          [ 0.14509805,  0.23137255,  0.30980393],
#          [ 0.6       ,  0.654902  ,  0.7411765 ]],
#
#         [[-0.38039216, -0.22352941, -0.14509805],
#          [-0.34901962, -0.19215687, -0.09803922],
#          [-0.3019608 , -0.15294118, -0.05098039],
#          ...,
#          [ 0.56078434,  0.6313726 ,  0.67058825],
#          [ 0.8745098 ,  0.94509804,  0.94509804],
#          [ 0.9372549 ,  0.9607843 ,  0.96862745]]],
#
#
#        [[[-0.7019608 , -0.42745098, -0.39607844],
#          [-0.6       , -0.3254902 , -0.29411766],
#          [-0.5372549 , -0.24705882, -0.21568628],
#          ...,
#          [ 0.654902  ,  0.69411767,  0.78039217],
#          [ 0.62352943,  0.6627451 ,  0.7647059 ],
#          [ 0.6313726 ,  0.67058825,  0.77254903]],
#
#         [[-0.6862745 , -0.4117647 , -0.38039216],
#          [-0.6       , -0.3254902 , -0.29411766],
#          [-0.5294118 , -0.23921569, -0.20784314],
#          ...,
#          [ 0.6392157 ,  0.6784314 ,  0.7647059 ],
#          [ 0.6313726 ,  0.67058825,  0.77254903],
#          [ 0.6313726 ,  0.67058825,  0.77254903]],
#
#         [[-0.69411767, -0.41960785, -0.3882353 ],
#          [-0.6       , -0.3254902 , -0.29411766],
#          [-0.5372549 , -0.24705882, -0.20784314],
#          ...,
#          [ 0.6313726 ,  0.67058825,  0.77254903],
#          [ 0.6313726 ,  0.67058825,  0.77254903],
#          [ 0.64705884,  0.6862745 ,  0.7882353 ]],
#
#         ...,
#
#         [[-0.24705882, -0.11372549,  0.01176471],
#          [-0.22352941, -0.10588235,  0.01960784],
#          [-0.22352941, -0.09803922,  0.01176471],
#          ...,
#          [ 0.15294118,  0.3019608 ,  0.7647059 ],
#          [ 0.25490198,  0.2627451 ,  0.34117648],
#          [ 0.22352941,  0.28627452,  0.3647059 ]],
#
#         [[-0.28627452, -0.16078432, -0.04313726],
#          [-0.28627452, -0.16078432, -0.05882353],
#          [-0.3019608 , -0.1764706 , -0.05882353],
#          ...,
#          [ 0.23137255,  0.2784314 ,  0.4117647 ],
#          [ 0.18431373,  0.23921569,  0.3254902 ],
#          [ 0.5686275 ,  0.654902  ,  0.70980394]],
#
#         [[-0.37254903, -0.24705882, -0.13725491],
#          [-0.31764707, -0.20784314, -0.09803922],
#          [-0.3019608 , -0.16862746, -0.04313726],
#          ...,
#          [ 0.5372549 ,  0.6156863 ,  0.64705884],
#          [ 0.90588236,  0.94509804,  0.9529412 ],
#          [ 0.92156863,  0.9529412 ,  0.94509804]]],
#
#
#        [[[-0.64705884, -0.3647059 , -0.31764707],
#          [-0.54509807, -0.2627451 , -0.21568628],
#          [-0.48235294, -0.15294118, -0.16862746],
#          ...,
#          [ 0.7176471 ,  0.7647059 ,  0.8352941 ],
#          [ 0.6862745 ,  0.7254902 ,  0.8117647 ],
#          [ 0.6862745 ,  0.7254902 ,  0.8117647 ]],
#
#         [[-0.6392157 , -0.35686275, -0.30980393],
#          [-0.54509807, -0.2627451 , -0.21568628],
#          [-0.46666667, -0.14509805, -0.14509805],
#          ...,
#          [ 0.6862745 ,  0.73333335,  0.8039216 ],
#          [ 0.6784314 ,  0.7176471 ,  0.8039216 ],
#          [ 0.6862745 ,  0.7254902 ,  0.8117647 ]],
#
#         [[-0.6392157 , -0.35686275, -0.30980393],
#          [-0.5372549 , -0.25490198, -0.20784314],
#          [-0.46666667, -0.15294118, -0.12941177],
#          ...,
#          [ 0.69411767,  0.73333335,  0.81960785],
#          [ 0.6784314 ,  0.7176471 ,  0.8039216 ],
#          [ 0.69411767,  0.73333335,  0.81960785]],
#
#         ...,
#
#         [[-0.12941177, -0.02745098,  0.09803922],
#          [-0.12941177, -0.02745098,  0.09803922],
#          [-0.10588235, -0.00392157,  0.12156863],
#          ...,
#          [ 0.3254902 ,  0.3647059 ,  0.84313726],
#          [ 0.3019608 ,  0.3254902 ,  0.46666667],
#          [ 0.2784314 ,  0.34117648,  0.4117647 ]],
#
#         [[-0.20784314, -0.09019608,  0.03529412],
#          [-0.20784314, -0.09019608,  0.03529412],
#          [-0.22352941, -0.09803922,  0.01176471],
#          ...,
#          [ 0.25490198,  0.34117648,  0.49019608],
#          [ 0.21568628,  0.29411766,  0.40392157],
#          [ 0.6156863 ,  0.67058825,  0.75686276]],
#
#         [[-0.29411766, -0.16078432, -0.03529412],
#          [-0.2627451 , -0.12941177, -0.00392157],
#          [-0.21568628, -0.07450981,  0.02745098],
#          ...,
#          [ 0.5764706 ,  0.654902  ,  0.70980394],
#          [ 0.92941177,  0.96862745,  0.9843137 ],
#          [ 0.9607843 ,  0.96862745,  0.9764706 ]]],
#
#
#        ...,
#
#
#        [[[-0.4509804 , -0.16862746, -0.16078432],
#          [-0.40392157, -0.12156863, -0.11372549],
#          [-0.3882353 , -0.10588235, -0.09803922],
#          ...,
#          [ 0.73333335,  0.77254903,  0.81960785],
#          [ 0.70980394,  0.7647059 ,  0.8117647 ],
#          [ 0.70980394,  0.7647059 ,  0.8117647 ]],
#
#         [[-0.44313726, -0.16078432, -0.15294118],
#          [-0.41960785, -0.13725491, -0.12941177],
#          [-0.39607844, -0.11372549, -0.10588235],
#          ...,
#          [ 0.73333335,  0.77254903,  0.81960785],
#          [ 0.70980394,  0.7647059 ,  0.8117647 ],
#          [ 0.7176471 ,  0.77254903,  0.81960785]],
#
#         [[-0.48235294, -0.16078432, -0.16078432],
#          [-0.43529412, -0.11372549, -0.11372549],
#          [-0.41960785, -0.12156863, -0.11372549],
#          ...,
#          [ 0.7176471 ,  0.77254903,  0.81960785],
#          [ 0.7176471 ,  0.77254903,  0.81960785],
#          [ 0.73333335,  0.7882353 ,  0.8352941 ]],
#
#         ...,
#
#         [[-0.14509805, -0.03529412,  0.07450981],
#          [-0.14509805, -0.03529412,  0.07450981],
#          [-0.14509805, -0.03529412,  0.07450981],
#          ...,
#          [ 0.3254902 ,  0.38039216,  0.69411767],
#          [ 0.34117648,  0.3647059 ,  0.5058824 ],
#          [ 0.29411766,  0.31764707,  0.41960785]],
#
#         [[-0.21568628, -0.10588235,  0.00392157],
#          [-0.20784314, -0.09019608, -0.01960784],
#          [-0.23137255, -0.11372549, -0.02745098],
#          ...,
#          [ 0.40392157,  0.42745098,  0.5058824 ],
#          [ 0.5137255 ,  0.56078434,  0.62352943],
#          [ 0.8980392 ,  0.92941177,  0.99215686]],
#
#         [[-0.12941177, -0.00392157,  0.09803922],
#          [-0.08235294,  0.05098039,  0.12156863],
#          [-0.02745098,  0.10588235,  0.19215687],
#          ...,
#          [ 0.88235295,  0.92941177,  0.9529412 ],
#          [ 0.9529412 ,  0.9843137 ,  0.9843137 ],
#          [ 0.94509804,  0.96862745,  0.9843137 ]]],
#
#
#        [[[-0.48235294, -0.16862746, -0.14509805],
#          [-0.4509804 , -0.13725491, -0.11372549],
#          [-0.3882353 , -0.11372549, -0.09803922],
#          ...,
#          [ 0.73333335,  0.7647059 ,  0.8352941 ],
#          [ 0.69411767,  0.73333335,  0.81960785],
#          [ 0.70980394,  0.7490196 ,  0.8352941 ]],
#
#         [[-0.4745098 , -0.16078432, -0.13725491],
#          [-0.44313726, -0.13725491, -0.11372549],
#          [-0.3882353 , -0.10588235, -0.09803922],
#          ...,
#          [ 0.7254902 ,  0.75686276,  0.827451  ],
#          [ 0.70980394,  0.7490196 ,  0.8352941 ],
#          [ 0.7176471 ,  0.75686276,  0.84313726]],
#
#         [[-0.49803922, -0.18431373, -0.16078432],
#          [-0.43529412, -0.12156863, -0.09803922],
#          [-0.40392157, -0.12156863, -0.11372549],
#          ...,
#          [ 0.70980394,  0.7647059 ,  0.8117647 ],
#          [ 0.70980394,  0.75686276,  0.827451  ],
#          [ 0.7254902 ,  0.77254903,  0.84313726]],
#
#         ...,
#
#         [[-0.14509805, -0.03529412,  0.07450981],
#          [-0.16078432, -0.05098039,  0.05882353],
#          [-0.16078432, -0.05098039,  0.05882353],
#          ...,
#          [ 0.30980393,  0.37254903,  0.70980394],
#          [ 0.34117648,  0.3647059 ,  0.5058824 ],
#          [ 0.30980393,  0.33333334,  0.41960785]],
#
#         [[-0.23137255, -0.10588235,  0.00392157],
#          [-0.24705882, -0.12156863, -0.01176471],
#          [-0.23921569, -0.10588235, -0.01960784],
#          ...,
#          [ 0.38039216,  0.4117647 ,  0.5058824 ],
#          [ 0.52156866,  0.5686275 ,  0.64705884],
#          [ 0.90588236,  0.94509804,  0.9843137 ]],
#
#         [[-0.12941177, -0.00392157,  0.09803922],
#          [-0.05882353,  0.07450981,  0.16862746],
#          [-0.03529412,  0.09803922,  0.18431373],
#          ...,
#          [ 0.8980392 ,  0.9529412 ,  0.9607843 ],
#          [ 0.9607843 ,  0.9843137 ,  0.9764706 ],
#          [ 0.96862745,  0.9843137 ,  0.9843137 ]]],
#
#
#        [[[-0.48235294, -0.18431373, -0.1764706 ],
#          [-0.43529412, -0.13725491, -0.12941177],
#          [-0.42745098, -0.12941177, -0.12156863],
#          ...,
#          [ 0.73333335,  0.7647059 ,  0.8352941 ],
#          [ 0.6862745 ,  0.7254902 ,  0.8117647 ],
#          [ 0.69411767,  0.73333335,  0.81960785]],
#
#         [[-0.4745098 , -0.1764706 , -0.16862746],
#          [-0.43529412, -0.13725491, -0.12941177],
#          [-0.41960785, -0.12156863, -0.11372549],
#          ...,
#          [ 0.7254902 ,  0.75686276,  0.827451  ],
#          [ 0.69411767,  0.73333335,  0.81960785],
#          [ 0.69411767,  0.73333335,  0.81960785]],
#
#         [[-0.48235294, -0.18431373, -0.1764706 ],
#          [-0.43529412, -0.13725491, -0.12941177],
#          [-0.4117647 , -0.11372549, -0.10588235],
#          ...,
#          [ 0.70980394,  0.75686276,  0.827451  ],
#          [ 0.69411767,  0.73333335,  0.81960785],
#          [ 0.70980394,  0.75686276,  0.827451  ]],
#
#         ...,
#
#         [[-0.16862746, -0.05882353,  0.05098039],
#          [-0.16078432, -0.05098039,  0.05882353],
#          [-0.16862746, -0.05882353,  0.05098039],
#          ...,
#          [ 0.3019608 ,  0.3647059 ,  0.7019608 ],
#          [ 0.31764707,  0.37254903,  0.45882353],
#          [ 0.21568628,  0.29411766,  0.37254903]],
#
#         [[-0.23921569, -0.10588235, -0.01960784],
#          [-0.22352941, -0.09019608, -0.00392157],
#          [-0.28627452, -0.14509805, -0.05882353],
#          ...,
#          [ 0.38039216,  0.40392157,  0.5058824 ],
#          [ 0.5058824 ,  0.5372549 ,  0.6156863 ],
#          [ 0.8745098 ,  0.92941177,  0.9843137 ]],
#
#         [[-0.16862746, -0.03529412,  0.05098039],
#          [-0.13725491, -0.00392157,  0.07450981],
#          [-0.04313726,  0.09019608,  0.1764706 ],
#          ...,
#          [ 0.8980392 ,  0.9607843 ,  0.9607843 ],
#          [ 0.9529412 ,  0.96862745,  0.9764706 ],
#          [ 0.94509804,  0.96862745,  0.9607843 ]]]], dtype=float32)

# %%
df.shape
# Out:
# (24, 256, 256, 3)

# %%
df_rgb = df[...,::-1].copy()

# %%
df_rgb.shape
# Out:
# (24, 256, 256, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(df[0])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #VGG test on another dataset

# %%
import zipfile 

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/SF_data/new_train.zip")
zip_ref.extractall()
zip_ref.close()

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

IMG_SIZE = (224,224)
train_data = image_dataset_from_directory(directory='new_train',
                                          validation_split=0.2,
                                          subset='training',
                                          seed=42,
                                          label_mode='categorical',
                                          image_size=IMG_SIZE)

valid_data = image_dataset_from_directory(directory='new_train',
                                          validation_split=0.2,
                                          subset='validation',
                                          seed=42,
                                          label_mode='categorical',
                                          image_size=IMG_SIZE)
# Out:
# Found 7000 files belonging to 10 classes.
# Using 5600 files for training.
# Found 7000 files belonging to 10 classes.
# Using 1400 files for validation.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 import tensorflow as tf
# ----> 2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Dense
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\api\_v2\keras\__init__.py:12
#       3 """Implementation of the Keras API, the high-level API of TensorFlow.
#       4
#       5 Detailed documentation and user guides are available at
#       6 [keras.io](https://keras.io).
#       7
#       8 """
#      10 import sys as _sys
# ---> 12 from keras import __version__
#      13 from keras.api._v2.keras import __internal__
#      14 from keras.api._v2.keras import activations
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\engine\functional.py:34
#      32 from keras.engine import input_spec
#      33 from keras.engine import node as node_module
# ---> 34 from keras.engine import training as training_lib
#      35 from keras.engine import training_utils
#      36 from keras.saving.saved_model import json_utils
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\engine\training.py:33
#      31 from keras.engine import base_layer
#      32 from keras.engine import base_layer_utils
# ---> 33 from keras.engine import compile_utils
#      34 from keras.engine import data_adapter
#      35 from keras.engine import input_layer as input_layer_module
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\engine\compile_utils.py:24
#      21 import tensorflow.compat.v2 as tf
#      23 from keras import losses as losses_mod
# ---> 24 from keras import metrics as metrics_mod
#      25 from keras.saving.experimental import saving_lib
#      26 from keras.utils import generic_utils
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\metrics\__init__.py:33
#      29 from keras.metrics.base_metric import clone_metrics
#      31 # Metric functions
#      32 # Individual metric classes
# ---> 33 from keras.metrics.metrics import AUC
#      34 from keras.metrics.metrics import Accuracy
#      35 from keras.metrics.metrics import BinaryAccuracy
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\metrics\metrics.py:28
#      25 import numpy as np
#      26 import tensorflow.compat.v2 as tf
# ---> 28 from keras import activations
#      29 from keras import backend
#      30 from keras.dtensor import utils as dtensor_utils
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\activations.py:21
#      17 import sys
#      19 import tensorflow.compat.v2 as tf
# ---> 21 import keras.layers.activation as activation_layers
#      22 from keras import backend
#      23 from keras.utils import generic_utils
#
# ImportError: cannot import name 'layers' from partially initialized module 'keras' (most likely due to a circular import) (c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\__init__.py)

# %%
# import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16

vgg_model = VGG16(weights='imagenet', input_shape=(224, 224, 3), include_top=True)
vgg_model.trainable = False
vgg_model.summary()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 # import tensorflow as tf
# ----> 2 from tensorflow.keras.applications.vgg16 import VGG16
#       4 vgg_model = VGG16(weights='imagenet', input_shape=(224, 224, 3), include_top=True)
#       5 vgg_model.trainable = False
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\api\_v2\keras\__init__.py:12
#       3 """Implementation of the Keras API, the high-level API of TensorFlow.
#       4
#       5 Detailed documentation and user guides are available at
#       6 [keras.io](https://keras.io).
#       7
#       8 """
#      10 import sys as _sys
# ---> 12 from keras import __version__
#      13 from keras.api._v2.keras import __internal__
#      14 from keras.api._v2.keras import activations
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\engine\functional.py:34
#      32 from keras.engine import input_spec
#      33 from keras.engine import node as node_module
# ---> 34 from keras.engine import training as training_lib
#      35 from keras.engine import training_utils
#      36 from keras.saving.saved_model import json_utils
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\engine\training.py:33
#      31 from keras.engine import base_layer
#      32 from keras.engine import base_layer_utils
# ---> 33 from keras.engine import compile_utils
#      34 from keras.engine import data_adapter
#      35 from keras.engine import input_layer as input_layer_module
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\engine\compile_utils.py:24
#      21 import tensorflow.compat.v2 as tf
#      23 from keras import losses as losses_mod
# ---> 24 from keras import metrics as metrics_mod
#      25 from keras.saving.experimental import saving_lib
#      26 from keras.utils import generic_utils
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\metrics\__init__.py:33
#      29 from keras.metrics.base_metric import clone_metrics
#      31 # Metric functions
#      32 # Individual metric classes
# ---> 33 from keras.metrics.metrics import AUC
#      34 from keras.metrics.metrics import Accuracy
#      35 from keras.metrics.metrics import BinaryAccuracy
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\metrics\metrics.py:28
#      25 import numpy as np
#      26 import tensorflow.compat.v2 as tf
# ---> 28 from keras import activations
#      29 from keras import backend
#      30 from keras.dtensor import utils as dtensor_utils
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\activations.py:21
#      17 import sys
#      19 import tensorflow.compat.v2 as tf
# ---> 21 import keras.layers.activation as activation_layers
#      22 from keras import backend
#      23 from keras.utils import generic_utils
#
# ImportError: cannot import name 'layers' from partially initialized module 'keras' (most likely due to a circular import) (c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\__init__.py)

# %%
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model

x = vgg_model.get_layer('fc2').output
x = Flatten(name='new_flatten')(x)
# x = Dense(256, activation='relu')(x)
# x = Dense(128, activation='relu')(x)
# x = Dense(32, activation='relu')(x)
output = Dense(10, activation='softmax')(x)

vgg_model = Model(vgg_model.input, output)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from tensorflow.keras.layers import Dense, Flatten
#       2 from tensorflow.keras.models import Model
#       4 x = vgg_model.get_layer('fc2').output
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\api\_v2\keras\__init__.py:12
#       3 """Implementation of the Keras API, the high-level API of TensorFlow.
#       4
#       5 Detailed documentation and user guides are available at
#       6 [keras.io](https://keras.io).
#       7
#       8 """
#      10 import sys as _sys
# ---> 12 from keras import __version__
#      13 from keras.api._v2.keras import __internal__
#      14 from keras.api._v2.keras import activations
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\engine\functional.py:34
#      32 from keras.engine import input_spec
#      33 from keras.engine import node as node_module
# ---> 34 from keras.engine import training as training_lib
#      35 from keras.engine import training_utils
#      36 from keras.saving.saved_model import json_utils
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\engine\training.py:33
#      31 from keras.engine import base_layer
#      32 from keras.engine import base_layer_utils
# ---> 33 from keras.engine import compile_utils
#      34 from keras.engine import data_adapter
#      35 from keras.engine import input_layer as input_layer_module
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\engine\compile_utils.py:24
#      21 import tensorflow.compat.v2 as tf
#      23 from keras import losses as losses_mod
# ---> 24 from keras import metrics as metrics_mod
#      25 from keras.saving.experimental import saving_lib
#      26 from keras.utils import generic_utils
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\metrics\__init__.py:33
#      29 from keras.metrics.base_metric import clone_metrics
#      31 # Metric functions
#      32 # Individual metric classes
# ---> 33 from keras.metrics.metrics import AUC
#      34 from keras.metrics.metrics import Accuracy
#      35 from keras.metrics.metrics import BinaryAccuracy
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\metrics\metrics.py:28
#      25 import numpy as np
#      26 import tensorflow.compat.v2 as tf
# ---> 28 from keras import activations
#      29 from keras import backend
#      30 from keras.dtensor import utils as dtensor_utils
#
# File c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\activations.py:21
#      17 import sys
#      19 import tensorflow.compat.v2 as tf
# ---> 21 import keras.layers.activation as activation_layers
#      22 from keras import backend
#      23 from keras.utils import generic_utils
#
# ImportError: cannot import name 'layers' from partially initialized module 'keras' (most likely due to a circular import) (c:\Users\malik\miniconda3\envs\tf-asl\lib\site-packages\keras\__init__.py)

# %%
vgg_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
vgg_model.fit(train_data, validation_data=valid_data, epochs=5)
# Out:
# Epoch 1/5
# 175/175 [==============================] - 50s 228ms/step - loss: 1.5777 - accuracy: 0.5011 - val_loss: 1.1205 - val_accuracy: 0.6114
# Epoch 2/5
# 175/175 [==============================] - 38s 218ms/step - loss: 0.9401 - accuracy: 0.6866 - val_loss: 1.1578 - val_accuracy: 0.6264
# Epoch 3/5
# 175/175 [==============================] - 37s 212ms/step - loss: 0.7225 - accuracy: 0.7468 - val_loss: 1.1038 - val_accuracy: 0.6471
# Epoch 4/5
# 175/175 [==============================] - 38s 215ms/step - loss: 0.5961 - accuracy: 0.7966 - val_loss: 1.0872 - val_accuracy: 0.6657
# Epoch 5/5
# 175/175 [==============================] - 38s 213ms/step - loss: 0.4880 - accuracy: 0.8370 - val_loss: 1.0874 - val_accuracy: 0.6643

# %%
vgg_model.layers[-2].output
# Out:
# <KerasTensor: shape=(None, 4096) dtype=float32 (created by layer 'new_flatten')>

# %%
from keras import backend as K
import tensorflow as tf

get_fc1_output = K.function([vgg_model.layers[0].input],[vgg_model.layers[-2].output])

test_sample = tf.random.uniform(shape=(1,224,224,3), minval=0, maxval=1)
# test_sample.shape
layer_output = get_fc1_output([test_sample])[0]
layer_output
# Out:
# array([[0.       , 0.       , 1.34051  , ..., 0.       , 0.       ,
#         0.5119427]], dtype=float32)

# %% [markdown]
# #test npy

# %%
import os

for dirpath, dirnames, filenames in os.walk("/content/drive/MyDrive/train_data"):
  print(f"there are {len(dirnames)} directories and {len(filenames)} files in {dirpath}")
# Out:
# there are 1047 directories and 0 files in /content/drive/MyDrive/train_data
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/husband
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/i
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/i love you
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/ice-skating
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/if
# there are 0 directories and 27 files in /content/drive/MyDrive/train_data/water
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/we
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/wash face
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/wall
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/visit
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/wake up
# there are 0 directories and 20 files in /content/drive/MyDrive/train_data/walk
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/vomit
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/warm
# there are 0 directories and 27 files in /content/drive/MyDrive/train_data/want
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/volleyball
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/waiter
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/wait
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/vegetable
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/vacuum
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/university
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/up
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/vietnam
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/use
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/upset
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/vice president
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/vacation
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/underwear
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/twins
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/umbrella
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/ugly
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/turtle
# there are 0 directories and 19 files in /content/drive/MyDrive/train_data/turkey
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/twenty
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/uncle
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/twelve
# there are 0 directories and 21 files in /content/drive/MyDrive/train_data/understand
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/two
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/tree
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/traffic
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/true
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/train
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/travel
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/towel
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/transfer
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/tuesday
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/truck
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/trigonometry
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/tomato
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/tiger
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/today
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/toast
# there are 0 directories and 20 files in /content/drive/MyDrive/train_data/tomorrow
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/time
# there are 0 directories and 30 files in /content/drive/MyDrive/train_data/tired
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/total
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/tie
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/together
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/thirteen
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/there
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/think
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/three
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/thursday
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/thin
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/thirsty
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/they
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/throw
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/ticket
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/that
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/tennis
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/thanks
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/thanksgiving
# there are 0 directories and 21 files in /content/drive/MyDrive/train_data/thank you
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/their
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/therapy
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/tend
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/that one
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/theater
# there are 0 directories and 29 files in /content/drive/MyDrive/train_data/teacher
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/tall
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/talk
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/teach
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/ten
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/tea
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/tell
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/tape
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/television
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/team
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/taiwan
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/swing
# there are 0 directories and 22 files in /content/drive/MyDrive/train_data/table
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/take care
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/take
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/take up
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/switzerland
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/swim
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/take off
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/swimming
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/surprise
# there are 0 directories and 18 files in /content/drive/MyDrive/train_data/sunday
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/sweetheart
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/sweet
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/sweater
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/sweep
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/sweden
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/surfing
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/sun
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/surf
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/subway
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/stubborn
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/sugar
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/student center
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/study
# there are 0 directories and 26 files in /content/drive/MyDrive/train_data/student
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/stupid
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/strong
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/stuck
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/summer
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/strict
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/stove
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/still
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/strawberry
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/steal
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/street
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/strange
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/stop
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/store
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/step
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/stamp
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/spring up
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/start
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/star
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/stand
# there are 0 directories and 21 files in /content/drive/MyDrive/train_data/spring
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/stay
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/steak
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/stairs
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/squirrel
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/south africa
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/spoon
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/spaghetti
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/spanish
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/spider
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/spell
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/spain
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/speech
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/sports
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/south america
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/sophomore
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/sometimes
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/son
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/some
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/sorry
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/soon
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/sore throat
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/soda
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/south
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/soup
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/soccer
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/soap
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/socks
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/snow
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/snob
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/sneeze
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/snowboard
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/so
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/snake
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/smart
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/skirt
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/skateboard
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/sixteen
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/slow
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/ski
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/slide
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/skiing
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/sleep
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/small
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/sleepy
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/since
# there are 0 directories and 21 files in /content/drive/MyDrive/train_data/sit
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/sink
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/six
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/silly
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/sign language
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/single
# there are 0 directories and 26 files in /content/drive/MyDrive/train_data/sister
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/sign
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/silver
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/shy
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/show
# there are 0 directories and 20 files in /content/drive/MyDrive/train_data/sick
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/short
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/shop
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/short hair
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/shrimp
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/should
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/shower
# there are 0 directories and 20 files in /content/drive/MyDrive/train_data/shoes
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/sheep
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/several
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/shock
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/seven
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/shelf
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/shelves
# there are 0 directories and 23 files in /content/drive/MyDrive/train_data/shirt
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/sew
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/seventeen
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/shark
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/send
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/secretary
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/seem
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/screwdriver
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/serious
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/see
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/sell
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/separate
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/senior
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/search
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/scarf
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/scotland
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/schedule
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/save
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/scientist
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/sandwich
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/scissors
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/science
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/saturday
# there are 0 directories and 28 files in /content/drive/MyDrive/train_data/school
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/run
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/rubber
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/salt
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/salad
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/russia
# there are 0 directories and 18 files in /content/drive/MyDrive/train_data/room
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/same
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/rude
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/roommate
# there are 0 directories and 21 files in /content/drive/MyDrive/train_data/sad
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/right
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/rest
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/retire
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/rock
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/rich
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/river
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/remember
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/research
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/ring
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/restaurant
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/rabbit
# there are 0 directories and 22 files in /content/drive/MyDrive/train_data/red
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/refuse
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/read
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/rainbow
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/ready
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/relationship
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/radio
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/refrigerator
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/rain
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/puerto rico
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/purchase
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/pumpkin
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/put_down
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/quarter
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/quiet
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/push
# there are 0 directories and 20 files in /content/drive/MyDrive/train_data/purple
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/question
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/pull
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/potato
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/principal
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/positive
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/pregnant
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/pow
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/psychologist
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/pshaw
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/psychology
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/proud
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/practice
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/plus
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/popcorn
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/poland
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/polite
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/police
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/police officer
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/portugal
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/pool
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/poor
# there are 0 directories and 19 files in /content/drive/MyDrive/train_data/please
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/plan
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/pie
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/pillow
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/plate
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/play
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/pig
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/play cardss
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/pizza
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/pineapple
# there are 0 directories and 19 files in /content/drive/MyDrive/train_data/pink
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/physics
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/photography
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/pet
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/pick up
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/philippines
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/piano
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/picture
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/personality
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/photographer
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/phone
# there are 0 directories and 19 files in /content/drive/MyDrive/train_data/pencil
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/pass
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/pear
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/pay
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/party
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/people
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/peach
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/pepper
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/perfect
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/past
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/oversleep
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/pants
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/outside
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/partner
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/paint
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/paper
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/pancake
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/parents
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/painting
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/out
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/open
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/one
# there are 0 directories and 28 files in /content/drive/MyDrive/train_data/orange
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/ok
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/often
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/old
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/oh i see
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/our
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/onion
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/only
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/not understand
# there are 0 directories and 19 files in /content/drive/MyDrive/train_data/nurse
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/number
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/nuts
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/not yet
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/ocean
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/office
# there are 0 directories and 19 files in /content/drive/MyDrive/train_data/now
# there are 0 directories and 22 files in /content/drive/MyDrive/train_data/nothing
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/not want
# there are 0 directories and 25 files in /content/drive/MyDrive/train_data/no
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/nose
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/not
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/norway
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/nineteen
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/not know
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/noon
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/not like
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/nosy
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/north
# there are 0 directories and 22 files in /content/drive/MyDrive/train_data/night
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/new
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/nice to meet you
# there are 0 directories and 33 files in /content/drive/MyDrive/train_data/nice
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/newspaper
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/next year
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/nine
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/niece
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/next week
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/next
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/must
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/nervous
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/mustache
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/near
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/need
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/negative
# there are 0 directories and 18 files in /content/drive/MyDrive/train_data/my
# there are 0 directories and 22 files in /content/drive/MyDrive/train_data/name
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/nephew
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/never
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/movie
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/mouse
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/music
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/motorcycle
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/mushroom
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/musician
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/mouth
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/mountain
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/museum
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/motivated
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/most
# there are 0 directories and 25 files in /content/drive/MyDrive/train_data/mother
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/money
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/moon
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/morning
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/monkey
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/more
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/more than
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/month
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/monday
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/mirror
# there are 0 directories and 24 files in /content/drive/MyDrive/train_data/milk
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/mix
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/midnight
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/metal
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/mischievous
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/mexico
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/minus
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/microwave
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/minute
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/mean
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/meaning
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/meet
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/meeting
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/meat
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/medicine
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/melon
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/measure
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/medium
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/mechanic
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/make
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/marry
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/match
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/me
# there are 0 directories and 23 files in /content/drive/MyDrive/train_data/man
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/many
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/march
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/math
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/maybe
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/manager
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/love it
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/loud
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/mad
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/magazine
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/love
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/mainstreamed
# there are 0 directories and 24 files in /content/drive/MyDrive/train_data/lost
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/lunch
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/major
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/lousy
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/long
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/look like
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/lonely
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/loan
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/long hair
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/look at
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/long ago
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/locker
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/lobster
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/living room
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/lion
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/listen
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/live
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/line up
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/library
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/librarian
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/light
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/list
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/lie
# there are 0 directories and 27 files in /content/drive/MyDrive/train_data/like
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/leave
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/less than
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/lazy
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/lemon
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/lawyer
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/letter
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/lead
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/left
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/lettuce
# there are 0 directories and 23 files in /content/drive/MyDrive/train_data/learn
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/law
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/language
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/last
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/later
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/laugh
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/laundry
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/last month
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/last week
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/late
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/last year
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/lamp
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/korea
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/kitchen
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/key
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/junior
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/lake
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/knife
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/ketchup
# there are 0 directories and 12 files in /content/drive/MyDrive/train_data/kiss
# there are 0 directories and 20 files in /content/drive/MyDrive/train_data/know
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/judge
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/jealous
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/janitor
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/japan
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/jam
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/juice
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/jump
# there are 0 directories and 20 files in /content/drive/MyDrive/train_data/jacket
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/join
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/jail
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/israel
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/ireland
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/intersection
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/island
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/iran
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/italy
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/iraq
# there are 0 directories and 3 files in /content/drive/MyDrive/train_data/introduce
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/internet
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/interpreter
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/interesting
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/india
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/in
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/important
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/innocent
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/inside
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/in law
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/inform
# there are 0 directories and 18 files in /content/drive/MyDrive/train_data/how_many
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/how
# there are 0 directories and 10 files in /content/drive/MyDrive/train_data/how are you
# there are 0 directories and 22 files in /content/drive/MyDrive/train_data/hurt
# there are 0 directories and 16 files in /content/drive/MyDrive/train_data/hungry
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/humble
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/hurry
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/horse
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hotel
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/hour
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hot
# there are 0 directories and 11 files in /content/drive/MyDrive/train_data/house
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hospital
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/holland
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/home
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hong kong
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/homework
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hockey
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/his
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/history
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hill
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hoddog
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hold on
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hippo
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/high school
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hike
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hit
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/help
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hello
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hi
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hearing help
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/here
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/health
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hearing
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hid
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/heart
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hear
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hard of hearing
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/he
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hashtag
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hat
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/head
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hard
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hate
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/headache
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/happy
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/have
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/gymnastics
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hamburger
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/halloween
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/half hour
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hair
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hallway
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/happen
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/gym
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/hanukkah
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/half
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/gray
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/gum
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/group
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/grass
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/green
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/greece
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/grocery store
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/grapes
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/guilty
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/grey
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/good afternoon
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/gossip
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/gone
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/graduate
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/good
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/golf
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/government
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/grandfather
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/good morning
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/grandmother
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/give
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/glass
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/go to
# ...
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/can
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/camera
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/camp
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/call
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/canada
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/candle
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/calendar
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/but
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/cabinets
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/buy
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/butterfly
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/cafeteria
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bye
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/butter
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/calculus
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/busy
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/cake
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bright
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/brown
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bus
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/brush teeth
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/brother
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/build
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/business
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/broke
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/building
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bug
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bowling
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bowl
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/break up
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/brave
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/boy
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/break
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/breakfast
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bread
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/boyfriend
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/both
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/boring
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bored
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/blanket
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/book
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/boss
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/blue
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/boat
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/born
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/boots
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bookstore
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/belt
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/big
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/best friend
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/biology
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/black
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/birthday
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bitter
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bird
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/better
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bicycle
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/beautiful
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bedroom
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/become
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bed
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/beer
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/beach
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/believe
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/before
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bear
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/beard
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bathroom
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/basketball
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bat
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bank
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bath
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/baseball
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/basement
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/ball
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bathtub
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/banana
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bad
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/awkward
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/back
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/awful
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bake
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/baby
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/autumn in love
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bacon
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/backpack
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/bald
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/athlete
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/aunt
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/autumn
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/asia
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/australia
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/artist
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/ask
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/asl
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/arrogant
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/austria
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/army
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/argue
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/area
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/arrive
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/around
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/appearance
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/apply
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/apple
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/appointment
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/argentina
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/answer
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/apartment
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/any
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/also
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/annoy
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/and
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/animal
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/america
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/angry
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/always
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/afternoon
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/again
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/algebra
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/all
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/all day
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/all night
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/alarm
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/airplane
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/alone
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/all morning
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/afraid
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/acquire
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/adopt
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/adult
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/actor
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/after
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/africa
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/accountant
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/accept
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/accident
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/24
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/27
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/50
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/30
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/28
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/26
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/about
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/absent
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/25
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/29
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/#apt
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/#asl
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/21
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/23
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/22
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/#ok
# there are 0 directories and 0 files in /content/drive/MyDrive/train_data/100
# there are 0 directories and 26 files in /content/drive/MyDrive/train_data/yellow
# there are 0 directories and 29 files in /content/drive/MyDrive/train_data/yes
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/yearbook
# there are 0 directories and 22 files in /content/drive/MyDrive/train_data/you
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/your
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/ﬁnish
# there are 0 directories and 1 files in /content/drive/MyDrive/train_data/ﬁshing
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/young
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/year
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/yesterday
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/with
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/worm
# there are 0 directories and 6 files in /content/drive/MyDrive/train_data/world
# there are 0 directories and 19 files in /content/drive/MyDrive/train_data/write
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/wood
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/worry
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/wrong
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/work
# there are 0 directories and 22 files in /content/drive/MyDrive/train_data/woman
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/wow
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/will
# there are 0 directories and 20 files in /content/drive/MyDrive/train_data/who
# there are 0 directories and 24 files in /content/drive/MyDrive/train_data/white
# there are 0 directories and 17 files in /content/drive/MyDrive/train_data/wife
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/window
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/wish
# there are 0 directories and 14 files in /content/drive/MyDrive/train_data/why
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/wine
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/win
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/winter
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/welcome
# there are 0 directories and 5 files in /content/drive/MyDrive/train_data/west
# there are 0 directories and 4 files in /content/drive/MyDrive/train_data/wet
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/which
# there are 0 directories and 29 files in /content/drive/MyDrive/train_data/what
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/whale
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/weekend
# there are 0 directories and 22 files in /content/drive/MyDrive/train_data/when
# there are 0 directories and 27 files in /content/drive/MyDrive/train_data/where
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/what's up
# there are 0 directories and 9 files in /content/drive/MyDrive/train_data/weather
# there are 0 directories and 15 files in /content/drive/MyDrive/train_data/watch
# there are 0 directories and 7 files in /content/drive/MyDrive/train_data/watermelon
# there are 0 directories and 2 files in /content/drive/MyDrive/train_data/wedding
# there are 0 directories and 8 files in /content/drive/MyDrive/train_data/weak
# there are 0 directories and 13 files in /content/drive/MyDrive/train_data/week
# there are 0 directories and 18 files in /content/drive/MyDrive/train_data/wednesday

# %%
import zipfile 

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/test_data.zip")
zip_ref.extractall()
zip_ref.close()

# %%
import numpy as np

for dirpath, dirnames, filenames in os.walk("/content/test_data"):
  for name in filenames:
    type(dirnames)
    # path = "/content/test_data/" + str(dirnames) +'/' + name
    # x = np.load(path)
    # print(len(x))
