# %%
import pandas as pd

# %%
test_df = pd.read_json('Datasets/MS-ASL/MS-ASL/MSASL_test.json')
test_df.head()
# Out:
#     org_text clean_text  start_time  signer_id  signer  start  end  \
# 0       beer       beer         0.0         20      40      0   59
# 1      enjoy      enjoy         0.0         11      39      0   54
# 2  emotional  emotional         0.0         20      40      0   30
# 3        key        key         0.0         92      -1      0   37
# 4        bad        bad         0.0         11      39      0   36
#
#                    file  label  height     fps  end_time  \
# 0   SignSchool Beer var    805     360  29.970     1.969
# 1              enjoy(1)    192     360  29.970     1.802
# 2  SignSchool Emotional    907     360  23.976     1.251
# 3        SignSchool Key    456     360  23.976     1.543
# 4                   BAD     81     360  29.970     1.201
#
#                                    url       text  \
# 0  www.youtube.com/watch?v=wX78EPtSuzU       beer
# 1  www.youtube.com/watch?v=OL02Odh2dRg      enjoy
# 2  www.youtube.com/watch?v=C59jcSo4fEI  emotional
# ...

# %% [markdown]
# checking if video is unavailable, using requests

# %%
import requests

def check_video_url(video_id):
    checker_url = "https://www.youtube.com/oembed?url=http://www.youtube.com/watch?v="
    video_url = checker_url + video_id

    request = requests.get(video_url)

    return request.status_code == 200

test="NjM7VsurXto"
print(check_video_url(test))

test="-DMFu-nAsok"
print(check_video_url(test))
# Out:
# True
# True

# %% [markdown]
# Removing unavailable videos

# %%
test_df.head()

#boolean list containing if a certain values if availble.
    #all videos will be marked as not available for the moment.
test_df["available"]=False
itr = next(test_df.iterrows())[1]
test_df["url"].head()
test_df["available"].head()
test_df.head()
# Out:
#     org_text clean_text  start_time  signer_id  signer  start  end  \
# 0       beer       beer         0.0         20      40      0   59
# 1      enjoy      enjoy         0.0         11      39      0   54
# 2  emotional  emotional         0.0         20      40      0   30
# 3        key        key         0.0         92      -1      0   37
# 4        bad        bad         0.0         11      39      0   36
#
#                    file  label  height     fps  end_time  \
# 0   SignSchool Beer var    805     360  29.970     1.969
# 1              enjoy(1)    192     360  29.970     1.802
# 2  SignSchool Emotional    907     360  23.976     1.251
# 3        SignSchool Key    456     360  23.976     1.543
# 4                   BAD     81     360  29.970     1.201
#
#                                    url       text  \
# 0  www.youtube.com/watch?v=wX78EPtSuzU       beer
# 1  www.youtube.com/watch?v=OL02Odh2dRg      enjoy
# 2  www.youtube.com/watch?v=C59jcSo4fEI  emotional
# ...

# %%
#if available, make the last column true;

for idx in range(0, len(test_df)-1):
    #last eleven elements
    code=test_df.loc[idx, "url"][-11:]#[24:]
    print(code)
    print(idx)
    if(check_video_url(code)):
        test_df.loc[idx, "available"]=True
# Out:
# wX78EPtSuzU
# 0
# OL02Odh2dRg
# 1
# C59jcSo4fEI
# 2
# Qs2ua1S6tg0
# 3
# -kgTBeOw95A
# 4
# ieLzL1Sl6SU
# 5
# xiJYYCuA2UA
# 6
# qSOspusLa3U
# 7
# 78bHeANdyYc
# 8
# deGERv54kIc
# 9
# ZcFkE7qjmcc
# 10
# a1NeXe8bhuo
# 11
# 2vYnEG9tSuA
# 12
# e22Pc68i_VE
# 13
# OdJuIwj6iYY
# 14
# BBCixbI_6C4
# 15
# BL90-ejIQ9Y
# 16
# G77ZoILMYw4
# 17
# G77ZoILMYw4
# 18
# G77ZoILMYw4
# 19
# G77ZoILMYw4
# 20
# G77ZoILMYw4
# 21
# G77ZoILMYw4
# 22
# G77ZoILMYw4
# 23
# G77ZoILMYw4
# 24
# G77ZoILMYw4
# 25
# G77ZoILMYw4
# 26
# G77ZoILMYw4
# 27
# G77ZoILMYw4
# 28
# G77ZoILMYw4
# 29
# G77ZoILMYw4
# 30
# G77ZoILMYw4
# 31
# G77ZoILMYw4
# 32
# G77ZoILMYw4
# 33
# G77ZoILMYw4
# 34
# G77ZoILMYw4
# 35
# G77ZoILMYw4
# 36
# G77ZoILMYw4
# 37
# G77ZoILMYw4
# 38
# G77ZoILMYw4
# 39
# G77ZoILMYw4
# 40
# cNtU2UH-2Rk
# 41
# cNtU2UH-2Rk
# 42
# cNtU2UH-2Rk
# 43
# cNtU2UH-2Rk
# 44
# cNtU2UH-2Rk
# 45
# cNtU2UH-2Rk
# 46
# cNtU2UH-2Rk
# 47
# cNtU2UH-2Rk
# 48
# cNtU2UH-2Rk
# 49
# cNtU2UH-2Rk
# 50
# cNtU2UH-2Rk
# 51
# cNtU2UH-2Rk
# 52
# ...

# %%
test_df["available"].head(100)
count=0
for i in range(0,100):
    if test_df["available"][i]==True:
        count+=1

#approximately 64 out of 100 videos are available.
print(count)

test_df.head()
# Out:
# 64
#     org_text clean_text  start_time  signer_id  signer  start  end  \
# 0       beer       beer         0.0         20      40      0   59
# 1      enjoy      enjoy         0.0         11      39      0   54
# 2  emotional  emotional         0.0         20      40      0   30
# 3        key        key         0.0         92      -1      0   37
# 4        bad        bad         0.0         11      39      0   36
#
#                    file  label  height     fps  end_time  \
# 0   SignSchool Beer var    805     360  29.970     1.969
# 1              enjoy(1)    192     360  29.970     1.802
# 2  SignSchool Emotional    907     360  23.976     1.251
# 3        SignSchool Key    456     360  23.976     1.543
# 4                   BAD     81     360  29.970     1.201
#
#                                    url       text  \
# 0  www.youtube.com/watch?v=wX78EPtSuzU       beer
# 1  www.youtube.com/watch?v=OL02Odh2dRg      enjoy
# 2  www.youtube.com/watch?v=C59jcSo4fEI  emotional
# ...

# %%
#exporting the json
    #df.to_json(r'Path to store the exported JSON file\File Name.json')
test_df.to_json(r"Datasets/MS-ASL/MS-ASL-with-new-labels/NEW-MSASL_test.json")
test_df.loc[i].to_json ("row {}.json".format (i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #exporting the json
#       2     #df.to_json(r'Path to store the exported JSON file\File Name.json')
# ----> 3 test_df.to_json(r"Datasets/MS-ASL/MS-ASL-with-new-labels/NEW-MSASL_test.json")
#       4 test_df.loc[i].to_json ("row {}.json".format (i))
#
# NameError: name 'test_df' is not defined
